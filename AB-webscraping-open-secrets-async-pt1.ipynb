# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import aiohttp
import asyncio

#insecure request warning from "verify=false" for each requests.get got annoying
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
district_7_url = 'https://www.opensecrets.org/races/candidates?cycle=2020&id=TN07&spec=N'

district_7_url_response = requests.get(district_7_url, verify=False)
district_7_url_response.status_code
# Out:
# 200

# %%
district_7_soup = BeautifulSoup(district_7_url_response.text)

# %%
candidate_info_df = pd.DataFrame()
party_dict={'R':'Republican','D':'Democrat','I':'Independent', 'L':'Libertarian', '3':'3rd Party'}

page_title = district_7_soup.find('h1',attrs={'class':'Hero-title'}).text
state = page_title[0:page_title.index('District')-1]
district_num = int(page_title[page_title.index('District')+9:page_title.index('District')+11])

candidate_name_list = []
candidate_party_list = []
is_incumbent_list = []
is_winner_list = []
vote_pct_list = []

candidate_blocks = district_7_soup.findAll('div',attrs={'class':'Members--bio u-richtext'})
#print(candidate_blocks) #-----> great reference for the complicated objects that results here
for block in candidate_blocks:
    
    #initialize variable for each candidate
    candidate_info_list = []
    is_incumbent = 'No'
    is_winner = 'No'
    
    #create list of "stripped strings" with all candidate info from each block
    for string in block.stripped_strings:
        candidate_info_list.append(repr(string))
    #print(candidate_info_list) #-----> great reference for the complicated list that results here
    
    #find candidate name, party, and vote % in candidate_info_list
    candidate_name=candidate_info_list[0][1:candidate_info_list[0].index('(')-1]
    
    candidate_party=candidate_info_list[0][candidate_info_list[0].index('(')+1]
    candidate_party = party_dict.get(candidate_party,candidate_party)
    
    #note: vote_pct was made into a float for ease of use later
    vote_pct = float(candidate_info_list[-1][2:candidate_info_list[-1].index('%')])
    
    #find whether or not candidate is incumbent within candidate_info_list
    for item in candidate_info_list:
        if item == "'Incumbent'":
            is_incumbent = 'Yes'
            
    #find whether or not candidate is winner within candidate_info_list
    for item in candidate_info_list:
        if item == "'Winner'":
            is_winner = 'Yes'            
            
    #make a lists for cleaned relevant information on each candidate
    candidate_name_list.append(candidate_name)
    candidate_party_list.append(candidate_party)
    is_incumbent_list.append(is_incumbent)
    is_winner_list.append(is_winner)
    vote_pct_list.append(vote_pct)
    

#Find money raised and spent
candidate_bigger_blocks = district_7_soup.findAll('div',attrs={'class':'Members--list-item'})
money_raised_list = []
money_spent_list = []
for bigger_block in candidate_bigger_blocks:
    money_table=pd.read_html(str(bigger_block.find('table',attrs={'class':'Members--table'})))[0]
    money_raised=money_table.loc[0,1]
    money_spent=money_table.loc[1,1]   
    #Put money raised and spent in lists as int values
    money_raised_list.append(int(money_raised[0:].replace(',','').replace('$','')))
    money_spent_list.append(int(money_spent[0:].replace(',','').replace('$','')))

    
#add cleaned info lists to the dataframe
candidate_info_df['Candidate_Name']=candidate_name_list
candidate_info_df['Candidate_Party']=candidate_party_list
candidate_info_df['State'] = state
candidate_info_df['District'] = district_num
candidate_info_df['Is_Incumbent?'] = is_incumbent_list
candidate_info_df['Is_Winner'] = is_winner_list
candidate_info_df['Percent_of_Vote_(%)'] = vote_pct_list
candidate_info_df['Money_Raised_($)'] = money_raised_list
candidate_info_df['Money_Spent_($)'] = money_spent_list

candidate_info_df
# Out:
#     Candidate_Name Candidate_Party      State  District Is_Incumbent?  \
# 0       Mark Green      Republican  Tennessee         7           Yes
# 1   Kiran Sreepada        Democrat  Tennessee         7            No
# 2     Ronald Brown     Independent  Tennessee         7            No
# 3  Scott Vieira Jr     Independent  Tennessee         7            No
#
#   Is_Winner  Percent_of_Vote_(%)  Money_Raised_($)  Money_Spent_($)
# 0       Yes                 69.9           1194960           935487
# 1        No                 27.3            206644           207191
# 2        No                  2.2              1750                0
# 3        No                  0.6               655             1049

# %%
#Pull Number of state reps and state abbreviations
state_abbrev_url = 'https://www.ssa.gov/international/coc-docs/states.html'
state_abbrev_url_response = requests.get(state_abbrev_url,verify=False)
#state_abbrev_url_response.status_code
state_abbrev_soup = BeautifulSoup(state_abbrev_url_response.text)
state_abbrev_df=pd.read_html(str(state_abbrev_soup.find('table')))[0]


state_rep_num_url = 'https://www.britannica.com/topic/United-States-House-of-Representatives-Seats-by-State-1787120'
state_rep_num_url_response = requests.get(state_rep_num_url,verify=False)
#state_rep_num_url_response.status_code
state_rep_num_soup = BeautifulSoup(state_rep_num_url_response.text)
state_rep_num_df = pd.read_html(str(state_rep_num_soup.find('table')))[0]

state_abbrev_df = state_abbrev_df.rename(columns = {0:'state', 1:'abbreviation'}).copy()
state_rep_num_df['state'] = state_rep_num_df['state'].str.upper()
#state_abbrev_df
#state_rep_num_df
state_info_df = state_abbrev_df.merge(state_rep_num_df,on='state',how='inner')
state_info_df
# Out:
#              state abbreviation  representatives
# 0          ALABAMA           AL                7
# 1           ALASKA           AK                1
# 2          ARIZONA           AZ                9
# 3         ARKANSAS           AR                4
# 4       CALIFORNIA           CA               52
# 5         COLORADO           CO                8
# 6      CONNECTICUT           CT                5
# 7         DELAWARE           DE                1
# 8          FLORIDA           FL               28
# 9          GEORGIA           GA               14
# 10          HAWAII           HI                2
# 11           IDAHO           ID                2
# 12        ILLINOIS           IL               17
# 13         INDIANA           IN                9
# 14            IOWA           IA                4
# 15          KANSAS           KS                4
# 16        KENTUCKY           KY                6
# 17       LOUISIANA           LA                6
# 18           MAINE           ME                2
# 19        MARYLAND           MD                8
# 20   MASSACHUSETTS           MA                9
# 21        MICHIGAN           MI               13
# 22       MINNESOTA           MN                8
# 23     MISSISSIPPI           MS                4
# 24        MISSOURI           MO                8
# 25         MONTANA           MT                2
# 26        NEBRASKA           NE                3
# 27          NEVADA           NV                4
# 28   NEW HAMPSHIRE           NH                2
# 29      NEW JERSEY           NJ               12
# 30      NEW MEXICO           NM                3
# 31        NEW YORK           NY               26
# 32  NORTH CAROLINA           NC               14
# 33    NORTH DAKOTA           ND                1
# 34            OHIO           OH               15
# 35        OKLAHOMA           OK                5
# 36          OREGON           OR                6
# 37    PENNSYLVANIA           PA               17
# 38    RHODE ISLAND           RI                2
# 39  SOUTH CAROLINA           SC                7
# 40    SOUTH DAKOTA           SD                1
# 41       TENNESSEE           TN                9
# 42           TEXAS           TX               38
# 43            UTAH           UT                4
# 44         VERMONT           VT                1
# 45        VIRGINIA           VA               11
# 46      WASHINGTON           WA               10
# 47   WEST VIRGINIA           WV                2
# 48       WISCONSIN           WI                8
# 49         WYOMING           WY                1

# %%
async def pull_candidates(url):
    #url_response = requests.get(url, verify=False)
    #url_soup = BeautifulSoup(url_response.text)
    
    candidate_info_df = pd.DataFrame()
    party_dict={'R':'Republican','D':'Democrat','I':'Independent', 'L':'Libertarian', '3':'3rd Party'}

    timeout = aiohttp.ClientTimeout(total=600)
    connector = aiohttp.TCPConnector(limit=10)
    async with aiohttp.ClientSession(connector=connector, timeout=timeout) as session:
         while True:
            try:
                async with session.get(url) as url_response:
                    url_text = await url_response.text()
                    url_soup = BeautifulSoup(url_text)
                    page_title = url_soup.find('h1',attrs={'class':'Hero-title'}).text
                    break
            except:
                print('Connection error loading url. Trying again...')
                time.sleep(5)

    state = page_title[0:page_title.index('District')-1]
    district_num = int(page_title[page_title.index('District')+9:page_title.index('District')+11])
    
    if int(page_title[page_title.index('District')+12:page_title.index('District')+16]) != 2020:
        print(f'{state} District {district_num} does not have a 2020 page!')
        pass
    else:
        candidate_name_list = []
        candidate_party_list = []
        is_incumbent_list = []
        is_winner_list = []
        vote_pct_list = []

        candidate_blocks = url_soup.findAll('div',attrs={'class':'Members--bio u-richtext'})
        #print(candidate_blocks) #-----> great reference for the complicated objects that results here
        for block in candidate_blocks:

            #initialize variable for each candidate
            candidate_info_list = []
            is_incumbent = 'No'
            is_winner = 'No'

            #create list of "stripped strings" with all candidate info from each block
            for string in block.stripped_strings:
                candidate_info_list.append(repr(string))
            #print(candidate_info_list) #-----> great reference for the complicated list that results here

            #find candidate name, party, and vote % in candidate_info_list
            candidate_name=candidate_info_list[0][1:candidate_info_list[0].index('(')-1]

            candidate_party=candidate_info_list[0][candidate_info_list[0].index('(')+1]
            candidate_party = party_dict.get(candidate_party,candidate_party)

            #note: vote_pct was made into a float for ease of use later
            try:
                vote_pct = float(candidate_info_list[-1][2:candidate_info_list[-1].index('%')])
            except:
                vote_pct = None

            #find whether or not candidate is incumbent within candidate_info_list
            for item in candidate_info_list:
                if item == "'Incumbent'":
                    is_incumbent = 'Yes'

            #find whether or not candidate is winner within candidate_info_list
            for item in candidate_info_list:
                if item == "'Winner'":
                    is_winner = 'Yes'            

            #make a lists for cleaned relevant information on each candidate
            candidate_name_list.append(candidate_name)
            candidate_party_list.append(candidate_party)
            is_incumbent_list.append(is_incumbent)
            is_winner_list.append(is_winner)
            vote_pct_list.append(vote_pct)

        try:
            if 'Yes' not in is_winner_list:
                print(f'{state} District {district_num} does not list a winner! Trying to determine winner by vote %...')
                is_winner_list[vote_pct_list.index(max(vote_pct_list))] = 'Yes'
                print(f'Successful!  {state} District {district_num} will list a winner determined by vote %.')
        except:
            print(f'Not successful. {state} District {district_num} will list NaN values for the "Is_Winner" column.')
            is_winner_list = [np.nan]*len(is_winner_list)
            pass       

        #Find money raised and spent
        candidate_bigger_blocks = url_soup.findAll('div',attrs={'class':'Members--list-item'})
        money_raised_list = []
        money_spent_list = []
        for bigger_block in candidate_bigger_blocks:
            money_table=pd.read_html(str(bigger_block.find('table',attrs={'class':'Members--table'})))[0]
            money_raised=money_table.loc[0,1]
            money_spent=money_table.loc[1,1]   
            #Put money raised and spent in lists as int values
            money_raised_list.append(int(money_raised[0:].replace(',','').replace('$','')))
            money_spent_list.append(int(money_spent[0:].replace(',','').replace('$','')))


        #add cleaned info lists to the dataframe
        candidate_info_df['Candidate_Name']=candidate_name_list
        candidate_info_df['Candidate_Party']=candidate_party_list
        candidate_info_df['State'] = state
        candidate_info_df['District'] = district_num
        candidate_info_df['Is_Incumbent?'] = is_incumbent_list
        candidate_info_df['Is_Winner'] = is_winner_list
        candidate_info_df['Percent_of_Vote_(%)'] = vote_pct_list
        candidate_info_df['Money_Raised_($)'] = money_raised_list
        candidate_info_df['Money_Spent_($)'] = money_spent_list

        return candidate_info_df

# %%
full_candidate_info_df = pd.DataFrame()

urls = []
for state, rep_num in zip(state_info_df['abbreviation'],state_info_df['representatives']):
    #print(state+" "+"{:02d}".format(rep_num))
    rep_num_list = [*range(1,rep_num+1)]
    rep_num_list_str = []
    for num in rep_num_list:
        num_string ="{:02d}".format(num)
        urls.append(f'https://www.opensecrets.org/races/candidates?cycle=2020&id={state}{num_string}&spec=N')

start_time = time.time()
print('Please wait. Compiling the full candidate info dataframe...')
for url in urls:
    result = await pull_candidates(url)
    full_candidate_info_df = pd.concat([full_candidate_info_df,result], ignore_index=True)
print(f"Complete! Compliling the full candidate info dataframe took: {time.time()-start_time:.2f} seconds")
# Out:
# Please wait. Compiling the full candidate info dataframe...
# Colorado District 8 does not have a 2020 page!
# Florida District 28 does not have a 2020 page!
# Hawaii District 1 does not list a winner! Trying to determine winner by vote %...
# Successful!  Hawaii District 1 will list a winner determine by vote %.
# Louisiana District 5 does not list a winner! Trying to determine winner by vote %...
# Not successful. Louisiana District 5 will list NaN values for the "Is_Winner" column.
# Montana District 2 does not have a 2020 page!
# New York District 22 does not list a winner! Trying to determine winner by vote %...
# Not successful. New York District 22 will list NaN values for the "Is_Winner" column.
# North Carolina District 14 does not have a 2020 page!
# Oregon District 6 does not have a 2020 page!
# Pennsylvania District 10 does not list a winner! Trying to determine winner by vote %...
# Successful!  Pennsylvania District 10 will list a winner determine by vote %.
# Texas District 37 does not have a 2020 page!
# Texas District 38 does not have a 2020 page!
# Complete! Compliling the full candidate info dataframe took: 212.28 seconds

# %%
full_candidate_info_df[(full_candidate_info_df['Candidate_Party']!='Republican') & (full_candidate_info_df['Candidate_Party']!='Democrat') & (full_candidate_info_df['Candidate_Party']!='Independent')].tail(50)
# Out:
#              Candidate_Name Candidate_Party           State  District  \
# 92          Angelica Duenas       3rd Party      California        29
# 141            Chris Milton       3rd Party        Colorado         3
# 146          Rebecca Keltie       3rd Party        Colorado         5
# 149       Jaimie Kulikowski       3rd Party        Colorado         6
# 159          Justin Paglino       3rd Party     Connecticut         3
# 240            Chase Oliver     Libertarian         Georgia         5
# 248            Jimmy Cooper       3rd Party         Georgia         8
# 260            Martin Cowen     Libertarian         Georgia        13
# 266   Jonathan Hoomanawanui       3rd Party          Hawaii         2
# 281            Bill Redpath     Libertarian        Illinois         6
# 283          Tracy Jennings       3rd Party        Illinois         7
# 321            Tonya Millis     Libertarian         Indiana         9
# 341        Robert Lee Perry     Libertarian        Kentucky         2
# 403    Jean-Michel Creviere       3rd Party        Michigan         2
# 436            Chris Kelley       3rd Party       Minnesota         5
# 478  Jonathan Royce Esteban     Libertarian          Nevada         4
# 516            Harry Burger       3rd Party        New York         2
# 533          Michael Madrid     Libertarian        New York        10
# 546        Michael Parietti       3rd Party        New York        17
# 564            Kevin Wilson     Libertarian        New York        25
# 570          Japheth Matemu     Libertarian  North Carolina         2
# 596              Kevin Kahn     Libertarian            Ohio         1
# 609            Brandon Lape     Libertarian            Ohio         7
# 620            John Stewart     Libertarian            Ohio        12
# 669         Liz Terwilliger     Libertarian    Pennsylvania        12
# 695       Larry Guy Hammond     Libertarian  South Carolina         7
# 720       Elliott Scheirman     Libertarian           Texas         2
# 727              Kevin Hale     Libertarian           Texas         5
# 742            Trey Holcomb     Libertarian           Texas        12
# 755               Ted Brown     Libertarian           Texas        17
# 773         Darren Hamilton     Libertarian           Texas        24
# 804              Joe Jarvis       3rd Party            Utah         2
# 807       Thomas G. McNeill       3rd Party            Utah         3
# 811         Jonia Broderick       3rd Party            Utah         4
# 835           Stevan Porter     Libertarian        Virginia        11
#
#     Is_Incumbent? Is_Winner  Percent_of_Vote_(%)  Money_Raised_($)  \
# 92             No        No                 43.4             78083
# 141            No        No                  1.0             12012
# 146            No        No                  0.8              2552
# 149            No        No                  0.9             72293
# 159            No        No                  1.5             29200
# 240            No        No                  NaN              9225
# 248            No        No                  NaN              8542
# 260            No        No                  NaN             13460
# 266            No        No                  2.2              1883
# 281            No        No                  1.7              9837
# 283            No        No                  6.2             65283
# 321            No        No                  4.3             10224
# 341            No        No                  2.1             12798
# 403            No        No                  0.7               281
# 436            No        No                  NaN            249583
# 478            No        No                  2.4              2788
# 516            No        No                  1.0              2430
# 533            No        No                  1.2             14326
# 546            No        No                  0.9             44787
# 564            No        No                  1.5              5128
# 570            No        No                  2.2               625
# 596            No        No                  3.6             12085
# 609            No        No                  3.3              3348
# 620            No        No                  3.0             75170
# 669            No        No                  NaN              6211
# 695            No        No                  NaN               199
# 720            No        No                  1.6             15374
# 727            No        No                  2.1             18405
# 742            No        No                  3.3               967
# 755            No        No                  3.2              3041
# 773            No        No                  1.6               570
# 804            No        No                  NaN             22989
# 807            No        No                  2.0              5516
# 811            No        No                  2.1             21394
# 835            No        No                  NaN               533
#
#      Money_Spent_($)
# 92             76627
# 141            12012
# 146             1495
# 149           110645
# 159            28670
# 240             5220
# 248             8528
# 260            13464
# 266             1522
# 281             9837
# 283            65283
# 321            10041
# 341             7825
# 403             1207
# 436           249583
# 478             1603
# 516              594
# 533            12149
# 546            19670
# 564             3417
# 570               54
# 596             8398
# 609             2713
# 620            66382
# 669             5937
# 695              199
# 720            14296
# 727             6508
# 742              457
# 755             3041
# 773              212
# 804            22989
# 807             5516
# 811            21265
# 835             1316

# %%
full_candidate_info_df.tail()
# Out:
#          Candidate_Name Candidate_Party      State  District Is_Incumbent?  \
# 872       Tricia Zunker        Democrat  Wisconsin         7            No
# 873      Mike Gallagher      Republican  Wisconsin         8           Yes
# 874        Amanda Stuck        Democrat  Wisconsin         8            No
# 875          Liz Cheney      Republican    Wyoming         1           Yes
# 876  Lynnette Grey Bull        Democrat    Wyoming         1            No
#
#     Is_Winner  Percent_of_Vote_(%)  Money_Raised_($)  Money_Spent_($)
# 872        No                 39.2           1261957          1232690
# 873       Yes                 64.0           3202905          2841801
# 874        No                 36.0            416978           399916
# 875       Yes                 68.6           3003883          3060167
# 876        No                 24.6            134597           132235

# %%
full_candidate_info_df[full_candidate_info_df['State']=='Texas'].tail(50)
# Out:
#                Candidate_Name Candidate_Party  State  District Is_Incumbent?  \
# 750         Monica De La Cruz      Republican  Texas        15            No
# 751          Veronica Escobar        Democrat  Texas        16           Yes
# 752  Irene Armendariz-Jackson      Republican  Texas        16            No
# 753             Pete Sessions      Republican  Texas        17            No
# 754              Rick Kennedy        Democrat  Texas        17            No
# 755                 Ted Brown     Libertarian  Texas        17            No
# 756        Sheila Jackson Lee        Democrat  Texas        18           Yes
# 757          Wendell Champion      Republican  Texas        18            No
# 758           Jodey Arrington      Republican  Texas        19           Yes
# 759                Tom Watson        Democrat  Texas        19            No
# 760            Joaquin Castro        Democrat  Texas        20           Yes
# 761               Mauro Garza      Republican  Texas        20            No
# 762                  Chip Roy      Republican  Texas        21           Yes
# 763               Wendy Davis        Democrat  Texas        21            No
# 764             Michael Felts     Independent  Texas        21            No
# 765              Sri Kulkarni        Democrat  Texas        22            No
# 766                Troy Nehls      Republican  Texas        22            No
# 767          Gina Ortiz Jones        Democrat  Texas        23            No
# 768             Tony Gonzales      Republican  Texas        23            No
# 769        Candace Valenzuela        Democrat  Texas        24            No
# 770            Beth Van Duyne      Republican  Texas        24            No
# 771           Stephen Kuzmich     Independent  Texas        24            No
# 772                Mark Bauer     Independent  Texas        24            No
# 773           Darren Hamilton     Libertarian  Texas        24            No
# 774            Roger Williams      Republican  Texas        25           Yes
# 775              Julie Oliver        Democrat  Texas        25            No
# 776           Michael Burgess      Republican  Texas        26           Yes
# 777            Carol Iannuzzi        Democrat  Texas        26            No
# 778             Michael Cloud      Republican  Texas        27           Yes
# 779      Ricardo De La Fuente        Democrat  Texas        27            No
# 780             Henry Cuellar        Democrat  Texas        28           Yes
# 781            Sandra Whitten      Republican  Texas        28            No
# 782             Sylvia Garcia        Democrat  Texas        29           Yes
# 783              Jaimy Blanco      Republican  Texas        29            No
# 784     Eddie Bernice Johnson        Democrat  Texas        30           Yes
# 785                Tre Pennie      Republican  Texas        30            No
# 786               John Carter      Republican  Texas        31           Yes
# 787                Donna Imam        Democrat  Texas        31            No
# 788              Colin Allred        Democrat  Texas        32           Yes
# 789         Genevieve Collins      Republican  Texas        32            No
# 790              Jason Sigmon     Independent  Texas        32            No
# 791               Marc Veasey        Democrat  Texas        33           Yes
# 792    Fabian Cordova Vasquez      Republican  Texas        33            No
# 793              Filemon Vela        Democrat  Texas        34           Yes
# 794              Rey Gonzalez      Republican  Texas        34            No
# 795             Lloyd Doggett        Democrat  Texas        35           Yes
# 796           Jennifer Sharon      Republican  Texas        35            No
# 797                Jason Mata     Independent  Texas        35            No
# 798               Brian Babin      Republican  Texas        36           Yes
# 799      Brandon Rashad Lewis        Democrat  Texas        36            No
#
#     Is_Winner  Percent_of_Vote_(%)  Money_Raised_($)  Money_Spent_($)
# 750        No                 47.6            344893           338832
# 751       Yes                 64.7           1135549          1087693
# 752        No                 35.3            168997           153671
# 753       Yes                 55.9           1447958          1658637
# 754        No                 40.9            200668           202096
# 755        No                  3.2              3041             3041
# 756       Yes                 73.3            924480           838414
# 757        No                 23.5            305645           271278
# 758       Yes                 74.8           2497184          1932700
# 759        No                 22.9             49405            60806
# 760       Yes                 64.7            674061           686934
# 761        No                 33.1            263293           240930
# 762       Yes                 52.0           5005639          4679362
# 763        No                 45.4          10263486         10201874
# 764        No                  NaN              3570             1851
# 765        No                 44.6           5639061          5630098
# 766       Yes                 51.5           1806655          1787448
# 767        No                 46.6           6755222          6842440
# 768       Yes                 50.5           2797133          2764108
# 769        No                 47.5           4886999          4875031
# 770       Yes                 48.8           3410852          3342442
# 771        No                  1.2            175504           201332
# 772        No                  0.9             26342            26542
# 773        No                  1.6               570              212
# 774       Yes                 55.9           2435121          3347267
# 775        No                 42.1           2190347          2176319
# 776       Yes                 60.6           1806588          2081391
# 777        No                 37.3             95937            95937
# 778       Yes                 63.1           1014427           829748
# 779        No                 34.9            312096           312096
# 780       Yes                 58.3           2655317          3650848
# 781        No                 39.0             24760            27354
# 782       Yes                 71.1            818984           758382
# 783        No                 27.4              4378                0
# 784       Yes                 77.5            589096           494547
# 785        No                 18.4            311109           305446
# 786       Yes                 53.4           2160187          2214487
# 787        No                 44.3           1035222          1035272
# 788       Yes                 52.0           5667725          5611747
# 789        No                 45.9           5923081          5915256
# 790        No                  0.7             11791            11651
# 791       Yes                 66.8           1621929          1613446
# 792        No                 25.2             36692            25585
# 793       Yes                 55.4            983026          1024180
# 794        No                 41.8             37118            37446
# 795       Yes                 65.4           1336576           424804
# 796        No                 30.0             19011            14442
# 797        No                  1.9              2632             2632
# 798       Yes                 73.6           1345351          1297185
# 799        No                 24.3             21714            12278

# %%
full_candidate_info_df[full_candidate_info_df['State']=='Louisiana'].tail(50)
# Out:
#           Candidate_Name Candidate_Party      State  District Is_Incumbent?  \
# 349        Steve Scalise      Republican  Louisiana         1           Yes
# 350      Cedric Richmond        Democrat  Louisiana         2           Yes
# 351         Clay Higgins      Republican  Louisiana         3           Yes
# 352  Robert Jon Anderson        Democrat  Louisiana         3            No
# 353       Braylon Harris        Democrat  Louisiana         3            No
# 354         Mike Johnson      Republican  Louisiana         4           Yes
# 355        Kenny Houston        Democrat  Louisiana         4            No
# 356          Luke Letlow      Republican  Louisiana         5            No
# 357         Lance Harris      Republican  Louisiana         5            No
# 358       Martin Lemelle        Democrat  Louisiana         5            No
# 359      Scotty Robinson      Republican  Louisiana         5            No
# 360     Candy Christophe        Democrat  Louisiana         5            No
# 361      Phillip Snowden        Democrat  Louisiana         5            No
# 362        Matthew Hasty      Republican  Louisiana         5            No
# 363        Garret Graves      Republican  Louisiana         6           Yes
# 364   Dartanyon Williams        Democrat  Louisiana         6            No
#
#     Is_Winner  Percent_of_Vote_(%)  Money_Raised_($)  Money_Spent_($)
# 349       Yes                 72.2          37262827         32830607
# 350       Yes                 63.6           1628289          1302079
# 351       Yes                 67.8            751498           720424
# 352        No                 11.6             63617            48015
# 353        No                 17.9             23006            15130
# 354       Yes                 60.4           1299787          1039393
# 355        No                 25.5             33677            33407
# 356       NaN                  NaN           1392822          1303757
# 357       NaN                  NaN            696805           687833
# 358       NaN                  NaN            173796           162747
# 359       NaN                  NaN            113903           113835
# 360       NaN                  NaN             77101           131161
# 361       NaN                  NaN             29481            28077
# 362       NaN                  NaN              2654             2615
# 363       Yes                 71.1           1743015          1200287
# 364        No                 25.6            111316            98114

# %%
full_candidate_info_df[full_candidate_info_df['State']=='Pennsylvania'].tail(50)
# Out:
#         Candidate_Name Candidate_Party         State  District Is_Incumbent?  \
# 646  Brian Fitzpatrick      Republican  Pennsylvania         1           Yes
# 647  Christina Finello        Democrat  Pennsylvania         1            No
# 648      Brendan Boyle        Democrat  Pennsylvania         2           Yes
# 649       Dwight Evans        Democrat  Pennsylvania         3           Yes
# 650     Madeleine Dean        Democrat  Pennsylvania         4           Yes
# 651     Kathy Barnette      Republican  Pennsylvania         4            No
# 652       Joe Tarshish     Independent  Pennsylvania         4            No
# 653   Mary Gay Scanlon        Democrat  Pennsylvania         5           Yes
# 654       Dasha Pruett      Republican  Pennsylvania         5            No
# 655   Chrissy Houlahan        Democrat  Pennsylvania         6           Yes
# 656        John Emmons      Republican  Pennsylvania         6            No
# 657        John McHugh     Independent  Pennsylvania         6            No
# 658         Susan Wild        Democrat  Pennsylvania         7           Yes
# 659    Matt Cartwright        Democrat  Pennsylvania         8           Yes
# 660         Jim Bognet      Republican  Pennsylvania         8            No
# 661         Dan Meuser      Republican  Pennsylvania         9           Yes
# 662        Gary Wegman        Democrat  Pennsylvania         9            No
# 663        Scott Perry      Republican  Pennsylvania        10           Yes
# 664  Eugene DePasquale        Democrat  Pennsylvania        10            No
# 665      Lloyd Smucker      Republican  Pennsylvania        11           Yes
# 666      Sarah Hammond        Democrat  Pennsylvania        11            No
# 667        Fred Keller      Republican  Pennsylvania        12           Yes
# 668        Lee Griffin        Democrat  Pennsylvania        12            No
# 669    Liz Terwilliger     Libertarian  Pennsylvania        12            No
# 670         John Joyce      Republican  Pennsylvania        13           Yes
# 671        Todd Rowley        Democrat  Pennsylvania        13            No
# 672  Guy Reschenthaler      Republican  Pennsylvania        14           Yes
# 673          Bill Marx        Democrat  Pennsylvania        14            No
# 674     Glenn Thompson      Republican  Pennsylvania        15           Yes
# 675         Mike Kelly      Republican  Pennsylvania        16           Yes
# 676      Kristy Gnibus        Democrat  Pennsylvania        16            No
# 677         Conor Lamb        Democrat  Pennsylvania        17           Yes
# 678       Sean Parnell      Republican  Pennsylvania        17            No
#
#     Is_Winner  Percent_of_Vote_(%)  Money_Raised_($)  Money_Spent_($)
# 646       Yes                 58.7           4203825          4272135
# 647        No                 41.3           2336814          2329748
# 648       Yes                 65.1           1556650           756317
# 649       Yes                 87.5            942386           781265
# 650       Yes                 56.0           1435995          1005928
# 651        No                 44.0           1000389           884640
# 652        No                  NaN             24038            23738
# 653       Yes                 60.3           1455042          1350276
# 654        No                 39.7            105146            82437
# 655       Yes                 54.7           3484484          1327283
# 656        No                 45.3            608859           601390
# 657        No                  NaN              6165             4410
# 658       Yes                 51.7           4581056          4528267
# 659       Yes                 51.7           3885136          4144070
# 660        No                 48.3           1519527          1386040
# 661       Yes                 68.2           1071961           944010
# 662        No                 31.8            188787           187348
# 663       Yes                 53.4           3956481          3839197
# 664        No                 46.6           4534580          4526684
# 665       Yes                 69.2           1349318           662704
# 666        No                 30.8             28733            23458
# 667       Yes                 71.8           1541938          1066158
# 668        No                 28.2             45850            44571
# 669        No                  NaN              6211             5937
# 670       Yes                 79.0           1119769           461229
# 671        No                 21.0             60348            67527
# 672       Yes                 67.8           2250282          1580488
# 673        No                 32.2             60403            45959
# 674       Yes                 76.3           1700061          1839073
# 675       Yes                 67.2           2239488          1319340
# 676        No                 32.8            584205           579453
# 677       Yes                 51.1           4063114          3448850
# 678        No                 48.9           3935774          3732399

# %%
compress_df_to_csv = dict(method='zip',
                        archive_name='full_candidate_info.csv')  
full_candidate_info_df.to_csv('full_candidate_info.zip', index=False,
          compression=compress_df_to_csv)
